# %% [markdown]
# # YOLO Fine-tuning on Sonar Debris Dataset
# Run this in Google Colab with GPU runtime enabled (Runtime > Change runtime type > GPU).

# %%
# !pip install ultralytics huggingface_hub

# %%
from huggingface_hub import snapshot_download

snapshot_download(
    repo_id="PINGEcosystem/sss-crab-pot-detection-ds",
    repo_type="dataset",
    local_dir="./sonar_dataset"
)

# %% [markdown]
# Check the downloaded dataset structure and locate (or write) a `data.yaml` file describing image/label paths and class names — YOLO training needs this.

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # start from pretrained weights
results = model.train(
    data="./sonar_dataset/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
)

# %% [markdown]
# After training, your best model weights will be at `runs/detect/train/weights/best.pt`. Download this file and place it at `backend/app/models/yolo_model.pt`.
